# %% [markdown]
# # Importing libraries and loading datasets¶

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
survey=pd.read_csv('NEW CUSTOMER RESEARCH FORM.csv')
survey.head()
# Out:
#                       Timestamp 1. What is your age range?  \
# 0  2023/02/12 12:34:59 PM GMT+1                    19 - 35
# 1  2023/02/12 12:59:17 PM GMT+1                    19 - 35
# 2   2023/02/12 1:05:50 PM GMT+1                    36 - 45
# 3   2023/02/12 1:12:55 PM GMT+1                    19 - 35
# 4   2023/02/12 1:37:09 PM GMT+1                    19 - 35
#
#   2. What is your Gender? 3. Where is your current location? (city, country)  \
# 0                  Female                             Strand,  South Africa
# 1                  Female                            Cape Town South Africa
# 2                    Male                                              Ghana
# 3                    Male                             Cape Town South Africa
# 4                  Female                            Capetown, South Africa
#
#   4. How often do you typically visit a laboratory for medical testing or procedures?  \
# 0                     Rarely(less than twice a year)
# ...

# %% [markdown]
# ## Data Pre-processing

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 19 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Timestamp                                                                                   60 non-null     object
#  1   1. What is your age range?                                                                  60 non-null     object
#  2   2. What is your Gender?                                                                     60 non-null     object
#  3   3. Where is your current location? (city, country)                                          60 non-null     object
#  4   4. How often do you typically visit a laboratory for medical testing or procedures?         60 non-null     object
# ...

# %%
survey.shape
# Out:
# (60, 19)

# %% [markdown]
# Dropping some unnecessary columns

# %%
survey1=survey.drop(['Timestamp'],axis='columns')
survey1.head()
# Out:
#   1. What is your age range? 2. What is your Gender?  \
# 0                    19 - 35                  Female
# 1                    19 - 35                  Female
# 2                    36 - 45                    Male
# 3                    19 - 35                    Male
# 4                    19 - 35                  Female
#
#   3. Where is your current location? (city, country)  \
# 0                             Strand,  South Africa
# 1                            Cape Town South Africa
# 2                                              Ghana
# 3                             Cape Town South Africa
# 4                            Capetown, South Africa
#
#   4. How often do you typically visit a laboratory for medical testing or procedures?  \
# 0                     Rarely(less than twice a year)
# 1                     Rarely(less than twice a year)
# 2                     Rarely(less than twice a year)
# 3                     Rarely(less than twice a year)
# ...

# %% [markdown]
# Obtaining some statistical information on the dataset

# %%
survey1.describe()
# Out:
#        8. How would you rate the process on a scale of 1 - 10?  \
# count                                          60.000000
# mean                                            7.216667
# std                                             1.914190
# min                                             1.000000
# 25%                                             6.000000
# 50%                                             7.000000
# 75%                                             8.000000
# max                                            10.000000
#
#        9. How would you rate the Laboratory staff?  \
# count                                    60.000000
# mean                                      7.283333
# std                                       1.896399
# min                                       2.000000
# 25%                                       6.000000
# 50%                                       7.000000
# 75%                                       9.000000
# ...

# %% [markdown]
# checking and filling null values

# %%
survey1.isnull().sum()
# Out:
# 1. What is your age range?                                                                     0
# 2. What is your Gender?                                                                        0
# 3. Where is your current location? (city, country)                                             0
# 4. How often do you typically visit a laboratory for medical testing or procedures?            0
# 5. Who referred you to the Laboratory?                                                         0
# 6. Would you say the process is fast or slow?                                                  0
# 7. Please describe your experience briefly?                                                    0
# 8. How would you rate the process on a scale of 1 - 10?                                        0
# 9. How would you rate the Laboratory staff?                                                    0
# 10. Have you ever experienced a result Mix-up?                                                 0
# ...

# %%
survey1['19. If you could see something improved about laboratory services, what would it be?']=survey1['19. If you could see something improved about laboratory services, what would it be?'].fillna('non_specified')
survey1['19. If you could see something improved about laboratory services, what would it be?']
survey1['11. How did you resolve it?']= survey1['11. How did you resolve it?'].fillna('non-specified')
survey1['11. How did you resolve it?']
# Out:
# 0                                          No I didn't
# 1                                         non-specified
# 2                                         non-specified
# 3                                                   Non
# 4                        Never experience result mix-up
# 5                               Haven't experienced one
# 6                                             I didn’t
# 7                                 I didn't happen to me
# 8                                   There was no mix up
# 9                                                  None
# 10                                I never experience it
# 11                     I haven't had an issue of mix up
# 12                                          No i havent
# 13                                 Not applicable to me
# 14                                      Not applicable
# 15                                                  Nil
# 16                                                   Na
# ...

# %% [markdown]
# ### EDA and visualizaton

# %%
process=survey1['6. Would you say the process is fast or slow?'].value_counts().head(10)
process
# Out:
# Fast and efficient      35
# Slow and efficient      23
# Slow and inefficient     2
# Name: 6. Would you say the process is fast or slow?, dtype: int64

# %%
process.plot(x='process',kind='pie',autopct='%1.1f%%',figsize=(14,12));

# %% [markdown]
# How often do you typically visit a laboratory for medical testing or procedures?

# %%
lab_visit=survey1['4. How often do you typically visit a laboratory for medical testing or procedures?'].value_counts().head(10)
lab_visit
# Out:
# Rarely(less than twice a year)           31
# Occasionally(2-3 times a year)           21
# Regularly( 3-4 times a year)              5
# Frequently( more than 4 times a year)     3
# Name: 4. How often do you typically visit a laboratory for medical testing or procedures?, dtype: int64

# %%
lab_visit.plot(kind='bar',figsize=(10,8),fontsize=18,title="Barchart Representation of visit to the Laboratory", color="green");

# %%
referred=survey1['5. Who referred you to the Laboratory?'].value_counts().head(10)
referred
# Out:
# Hospital          29
# I came myself     21
# Private doctor     9
# Employer           1
# Name: 5. Who referred you to the Laboratory?, dtype: int64

# %%
referred.plot(kind='bar',figsize=(10,8),fontsize=18,title="Barchart Representation of referral to the Laboratory", color="green");

# %%
mix_up= survey['10. Have you ever experienced a result Mix-up?'].value_counts()
mix_up
# Out:
# No I haven't    59
# Yes I have       1
# Name: 10. Have you ever experienced a result Mix-up?, dtype: int64

# %%
mix_up.plot(x='mix_up',kind='pie',autopct='%1.1f%%',figsize=(10,8));

# %%
online_booking= survey['15. Would you love to book an appointment online?']. value_counts()
online_booking
# Out:
# Yes    43
# No     17
# Name: 15. Would you love to book an appointment online?, dtype: int64

# %%
online_booking.plot(x='online_booking',kind='pie',autopct='%1.1f%%',figsize=(10,8));

# %%
result_format= survey['17. Would you prefer to collect your test result physically or sent to you online?'].value_counts()
result_format
# Out:
# Online        43
# Physically    17
# Name: 17. Would you prefer to collect your test result physically or sent to you online?, dtype: int64

# %%
result_format.plot(x='result_format',kind='pie',autopct='%1.1f%%',figsize=(10,8));

# %% [markdown]
# How often do you typically visit a laboratory for medical testing or procedures?

# %%
lab_visit=survey1['4. How often do you typically visit a laboratory for medical testing or procedures?'].value_counts().head(10)
lab_visit
# Out:
# Rarely(less than twice a year)           31
# Occasionally(2-3 times a year)           21
# Regularly( 3-4 times a year)              5
# Frequently( more than 4 times a year)     3
# Name: 4. How often do you typically visit a laboratory for medical testing or procedures?, dtype: int64

# %%
lab_visit.plot(kind='bar',figsize=(10,8),fontsize=18,title="Barchart Representation of visit to the Laboratory", color="green");

# %%
referred=survey1['5. Who referred you to the Laboratory?'].value_counts().head(10)
referred
# Out:
# Hospital          29
# I came myself     21
# Private doctor     9
# Employer           1
# Name: 5. Who referred you to the Laboratory?, dtype: int64

# %%
referred.plot(kind='bar',figsize=(8,8),fontsize=10,title="Barchart Representation of referral to the Laboratory", color="green");

# %% [markdown]
# ## Machine learning

# %% [markdown]
# ##### Use decision tree

# %% [markdown]
# ##### Based on the observations, how many more people are likely to use laboratory services in the future

# %%
survey1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 18 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   1. What is your age range?                                                                  60 non-null     object
#  1   2. What is your Gender?                                                                     60 non-null     object
#  2   3. Where is your current location? (city, country)                                          60 non-null     object
#  3   4. How often do you typically visit a laboratory for medical testing or procedures?         60 non-null     object
#  4   5. Who referred you to the Laboratory?                                                      60 non-null     object
# ...

# %% [markdown]
# ##### drop some unnecessary columns

# %%
survey1=survey1.drop(['1. What is your age range?','2. What is your Gender?','3. Where is your current location? (city, country)','5. Who referred you to the Laboratory?', '7. Please describe your experience briefly?','11. How did you resolve it?','12. How likely are you to continue using the Laboratory services in the future.','19. If you could see something improved about laboratory services, what would it be?'], axis='columns')
survey1
# Out:
#    4. How often do you typically visit a laboratory for medical testing or procedures?  \
# 0                      Rarely(less than twice a year)
# 1                      Rarely(less than twice a year)
# 2                      Rarely(less than twice a year)
# 3                      Rarely(less than twice a year)
# 4                      Rarely(less than twice a year)
# 5                      Occasionally(2-3 times a year)
# 6                      Rarely(less than twice a year)
# 7                      Rarely(less than twice a year)
# 8                      Rarely(less than twice a year)
# 9                      Occasionally(2-3 times a year)
# 10                     Occasionally(2-3 times a year)
# 11                     Occasionally(2-3 times a year)
# 12                     Rarely(less than twice a year)
# 13                     Rarely(less than twice a year)
# 14                     Occasionally(2-3 times a year)
# 15                     Rarely(less than twice a year)
# ...

# %% [markdown]
# ### rename columns

# %%
survey1.columns=['visit','process','rate','staff','mix_up','recommend','book','preference','collection','satisfication']
survey1.head(3)
# Out:
#                             visit             process  rate  staff  \
# 0  Rarely(less than twice a year)  Fast and efficient     8      9
# 1  Rarely(less than twice a year)  Fast and efficient    10     10
# 2  Rarely(less than twice a year)  Fast and efficient     8      7
#
#          mix_up recommend book  preference collection   satisfication
# 0  No I haven't       Yes  Yes        Home     Online  Very Satisfied
# 1  No I haven't       Yes   No        Home     Online  Very Satisfied
# 2  No I haven't       Yes   No  Laboratory     Online  Very Satisfied

# %% [markdown]
# ### Converting some columns from words to digit using labelEncoder and fit transform

# %%
from sklearn.preprocessing import LabelEncoder

le_visit=LabelEncoder()
le_process=LabelEncoder()
le_mix_up=LabelEncoder()
le_recommend=LabelEncoder()
le_book=LabelEncoder()
le_preference=LabelEncoder()
le_collection=LabelEncoder()
le_satisfication=LabelEncoder()

# %%
survey1['visit']=le_visit.fit_transform(survey1['visit'])
survey1['process']=le_process.fit_transform(survey1['process'])
survey1['mix_up']=le_mix_up.fit_transform(survey1['mix_up'])
survey1['recommend']=le_recommend.fit_transform(survey1['recommend'])
survey1['book']=le_book.fit_transform(survey1['book'])
survey1['preference']=le_preference.fit_transform(survey1['preference'])
survey1['collection']=le_collection.fit_transform(survey1['collection'])
survey1['satisfication']=le_satisfication.fit_transform(survey1['satisfication'])

# %%
survey1.head(5)
# Out:
#    visit  process  rate  staff  mix_up  recommend  book  preference  \
# 0      2        0     8      9       0          1     1           0
# 1      2        0    10     10       0          1     0           0
# 2      2        0     8      7       0          1     0           1
# 3      2        0    10     10       0          1     1           1
# 4      2        0     9     10       0          1     0           1
#
#    collection  satisfication
# 0           0              1
# 1           0              1
# 2           0              1
# 3           0              1
# 4           1              1

# %% [markdown]
# ## Dropping out the target variable

# %%
input=survey1.drop(['satisfication'],axis='columns')
target=survey1['satisfication']
target
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     0
# 7     0
# 8     1
# 9     0
# 10    0
# 11    1
# 12    1
# 13    1
# 14    0
# 15    1
# 16    0
# 17    1
# 18    1
# 19    0
# 20    1
# 21    1
# 22    1
# 23    0
# 24    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    0
# 30    1
# 31    1
# 32    1
# 33    0
# 34    0
# 35    0
# 36    1
# 37    0
# 38    0
# 39    1
# 40    0
# 41    0
# 42    0
# 43    1
# 44    1
# 45    1
# 46    1
# 47    1
# 48    1
# 49    1
# 50    0
# 51    1
# 52    1
# 53    1
# 54    1
# 55    1
# 56    0
# 57    0
# 58    0
# 59    1
# Name: satisfication, dtype: int32

# %%
input.head(3)
# Out:
#    visit  process  rate  staff  mix_up  recommend  book  preference  \
# 0      2        0     8      9       0          1     1           0
# 1      2        0    10     10       0          1     0           0
# 2      2        0     8      7       0          1     0           1
#
#    collection
# 0           0
# 1           0
# 2           0

# %% [markdown]
# importing the model

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()

# %%
model.fit(input,target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# training the model

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input,target,test_size=0.3)

# %%
model.score(input,target)
# Out:
# 0.9833333333333333

# %% [markdown]
# Our model shows an accuracy score of 98%
